# %%
# import os
# import numpy as np
# import socketio
# import requests
# import re
# import json
# import librosa
# import soundfile as sf
# from allosaurus.app import read_recognizer
# import pickle

# %%
from text2mouth_module import Text2MouthShape
# Out:
# ['มีหรือไม่มีคะ', 'เกิน24ชั่วโมงหรือไม่เกินคะ', 'มีการล้มหรือกระแทกมาหรือไม่คะ', 'มีการได้รับอุบัติเหตุมาหรือไม่คะ', 'ขอโทษนะคะ รบกวนตอบว่าเคยหรือไม่เคยค่ะ', 'ขอโทษนะคะ รบกวนตอบว่ามีหรือไม่มีค่ะ', 'ขอโทษด้วยค่ะ รบกวนช่วยตอบว่าต้องการหรือไม่ต้องการค่ะ', 'รักษาตัวเองดีๆนะคะ', 'คุณอยากรู้เรื่องอะไรคะ', 'มีอาการมือจีบ หรือไม่คะ', 'ช่วยตอบว่ามีหรือไม่มีด้วยค่ะ', 'ห้องอุบัติเหตุและฉุกเฉิน', 'มีอาการเกิน24ชั่วโมง หรือไม่เกินคะ', 'ช่วยตอบว่าเกินหรือไม่เกินด้วยค่ะ', 'ห้องตรวจอายุรกรรม', 'มีอาการมาเกิน48ชั่วโมง หรือไม่เกินคะ', 'ช่วยตอบว่าเกินหรือไม่เกินค่ะ', 'มีอาการปวดฟัน หรือไม่คะ', 'ช่วยตอบว่ามีหรือไม่มีค่ะ', 'ห้องตรวจทันตกรรม', 'มีการโดนแมลงหรือสัตว์กัดต่อยมา หรือไม่คะ', 'ห้องตรวจโรคทั่วไป', 'มีการได้รับอุบัติเหตุมา หรือไม่คะ', 'เกิน24ชั่วโมง หรือไม่เกินคะ', 'มีแผลบวมแดง หรือไม่คะ', 'มีไข้ หรือไม่คะ', 'มีไอด้วย หรือไม่คะ', 'แล้วมีอาการเจ็บคอ หรือไม่คะ', 'มีอาการจุกแน่น หรือไม่คะ', 'แล้วมีอาการเหนื่อยร่วมด้วย หรือไม่คะ', 'มีอาการแสบท้องร่วมด้วย หรือไม่คะ', 'มีคลำเจอก้อน หรือไม่คะ', 'รบกวนช่
# ...

# %%
t2m = Text2MouthShape()

# %%
'อาคารผู้ป่วยนอก ชั้น 1 ข้างบันได'
# Out:
# 'อาคารผู้ป่วยนอก ชั้น 1 ข้างบันได'

# %%
# t2m.msg_txt2blendshape('บันทึกรายการเรียบร้อยกรุณาพบแพทย์ที่ห้องศัลยกรรมกระดูกค่ะ')
